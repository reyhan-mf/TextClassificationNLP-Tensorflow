# %%
import pandas as pd
df = pd.read_csv('imdb_indonesian_movies_2.csv')
df = df.drop(columns=['judul_film'])

# %%
category = pd.get_dummies(df.genre)
df_baru = pd.concat([df, category], axis=1)
df_baru = df_baru.drop(columns='genre')
df_baru
# Out:
#                                      ringkasan_sinopsis  Drama  Horor  Komedi  \
# 0     Raden Mas Said putra sulung Tumenggung Wilarik...   True  False   False
# 1     Soe Hok Gie adalah seorang aktivis yang hidup ...   True  False   False
# 2     Guru Bangsa Tjokroaminoto menceritakan tentang...   True  False   False
# 3     POL menceritakan kisah hidup yang luar biasa d...   True  False   False
# 4     Perjalanan pahlawan Indonesia KH Ahmad Dahlan ...   True  False   False
# ...                                                 ...    ...    ...     ...
# 1000  Winter in Tokyo berpusat pada kehidupan Ishida...  False  False   False
# 1001  Markonah melarikan diri ke Jakarta karena akan...  False  False   False
# 1002  Tempat aking lebih dari 36 jam, Last Night ada...  False  False   False
# 1003  Proyek baru ini adalah tentang seorang lelaki ...  False  False   False
# 1004  Atika (Meriam Bellina) mantan penyanyi tenar, ...  False  False   False
#
#        Laga  Romantis
# 0     False     False
# 1     False     False
# 2     False     False
# 3     False     False
# 4     False     False
# ...     ...       ...
# 1000  False      True
# 1001  False      True
# 1002  False      True
# 1003  False      True
# 1004  False      True
#
# [1005 rows x 6 columns]

# %%
sinopsis = df_baru['ringkasan_sinopsis'].values
label = df_baru[['Drama', 'Horor', 'Komedi', 'Laga', 'Romantis']].values

# %%
from sklearn.model_selection import train_test_split
sinopsis_latih, sinopsis_test, label_latih, label_test = train_test_split(sinopsis, label, test_size=0.2)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
 
tokenizer = Tokenizer(num_words=5000, oov_token='x')
tokenizer.fit_on_texts(sinopsis_latih) 
tokenizer.fit_on_texts(sinopsis_test)
 
sekuens_latih = tokenizer.texts_to_sequences(sinopsis_latih)
sekuens_test = tokenizer.texts_to_sequences(sinopsis_test)
 
padded_latih = pad_sequences(sekuens_latih) 
padded_test = pad_sequences(sekuens_test)

# %%
import tensorflow as tf
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(input_dim=5000, output_dim=16),
    tf.keras.layers.LSTM(64),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(5, activation='softmax')
])
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
num_epochs = 30
history = model.fit(padded_latih, label_latih, epochs=num_epochs, 
                    validation_data=(padded_test, label_test), verbose=2)
# Out:
# Epoch 1/30
# 26/26 - 12s - loss: 1.6104 - accuracy: 0.1754 - val_loss: 1.6092 - val_accuracy: 0.2139 - 12s/epoch - 474ms/step
# Epoch 2/30
# 26/26 - 10s - loss: 1.6071 - accuracy: 0.2239 - val_loss: 1.6083 - val_accuracy: 0.2388 - 10s/epoch - 380ms/step
# Epoch 3/30
# 26/26 - 11s - loss: 1.5676 - accuracy: 0.3532 - val_loss: 1.5848 - val_accuracy: 0.3035 - 11s/epoch - 413ms/step
# Epoch 4/30
# 26/26 - 11s - loss: 1.3813 - accuracy: 0.4316 - val_loss: 1.5983 - val_accuracy: 0.2836 - 11s/epoch - 431ms/step
# Epoch 5/30
# 26/26 - 11s - loss: 1.1080 - accuracy: 0.5112 - val_loss: 1.8265 - val_accuracy: 0.2985 - 11s/epoch - 415ms/step
# Epoch 6/30
# 26/26 - 13s - loss: 0.8297 - accuracy: 0.6331 - val_loss: 2.0460 - val_accuracy: 0.2338 - 13s/epoch - 504ms/step
# Epoch 7/30
# 26/26 - 21s - loss: 0.5842 - accuracy: 0.7711 - val_loss: 2.6111 - val_accuracy: 0.2438 - 21s/epoch - 799ms/step
# Epoch 8/30
# 26/26 - 15s - loss: 0.3326 - accuracy: 0.8930 - val_loss: 3.1265 - val_accuracy: 0.2985 - 15s/epoch - 571ms/step
# Epoch 9/30
# 26/26 - 11s - loss: 0.1753 - accuracy: 0.9478 - val_loss: 3.2731 - val_accuracy: 0.2687 - 11s/epoch - 407ms/step
# Epoch 10/30
# 26/26 - 11s - loss: 0.1209 - accuracy: 0.9714 - val_loss: 3.6592 - val_accuracy: 0.2338 - 11s/epoch - 428ms/step
# Epoch 11/30
# 26/26 - 12s - loss: 0.0427 - accuracy: 0.9925 - val_loss: 4.2806 - val_accuracy: 0.2488 - 12s/epoch - 456ms/step
# Epoch 12/30
# 26/26 - 12s - loss: 0.0343 - accuracy: 0.9950 - val_loss: 4.4911 - val_accuracy: 0.2388 - 12s/epoch - 466ms/step
# Epoch 13/30
# 26/26 - 22s - loss: 0.0197 - accuracy: 0.9938 - val_loss: 4.9709 - val_accuracy: 0.2537 - 22s/epoch - 856ms/step
# Epoch 14/30
# 26/26 - 14s - loss: 0.0133 - accuracy: 0.9975 - val_loss: 5.1682 - val_accuracy: 0.2388 - 14s/epoch - 527ms/step
# Epoch 15/30
# 26/26 - 11s - loss: 0.0114 - accuracy: 0.9988 - val_loss: 5.3166 - val_accuracy: 0.2786 - 11s/epoch - 432ms/step
# Epoch 16/30
# 26/26 - 11s - loss: 0.0200 - accuracy: 0.9975 - val_loss: 5.0637 - val_accuracy: 0.2289 - 11s/epoch - 428ms/step
# Epoch 17/30
# 26/26 - 19s - loss: 0.0138 - accuracy: 0.9975 - val_loss: 5.3076 - val_accuracy: 0.2836 - 19s/epoch - 741ms/step
# Epoch 18/30
# 26/26 - 19s - loss: 0.0096 - accuracy: 0.9988 - val_loss: 5.6074 - val_accuracy: 0.2537 - 19s/epoch - 712ms/step
# Epoch 19/30
# 26/26 - 15s - loss: 0.0081 - accuracy: 0.9988 - val_loss: 5.5091 - val_accuracy: 0.2637 - 15s/epoch - 581ms/step
# Epoch 20/30
# 26/26 - 21s - loss: 0.0095 - accuracy: 0.9988 - val_loss: 5.6341 - val_accuracy: 0.2388 - 21s/epoch - 806ms/step
# Epoch 21/30
# 26/26 - 16s - loss: 0.0059 - accuracy: 0.9988 - val_loss: 5.6907 - val_accuracy: 0.2438 - 16s/epoch - 618ms/step
# Epoch 22/30
# 26/26 - 20s - loss: 0.0067 - accuracy: 0.9975 - val_loss: 5.7369 - val_accuracy: 0.2687 - 20s/epoch - 771ms/step
# Epoch 23/30
# 26/26 - 21s - loss: 0.0050 - accuracy: 0.9988 - val_loss: 5.9212 - val_accuracy: 0.2687 - 21s/epoch - 816ms/step
# Epoch 24/30
# 26/26 - 20s - loss: 0.0080 - accuracy: 0.9988 - val_loss: 5.9282 - val_accuracy: 0.2736 - 20s/epoch - 774ms/step
# Epoch 25/30
# 26/26 - 20s - loss: 0.0069 - accuracy: 0.9975 - val_loss: 5.8354 - val_accuracy: 0.2438 - 20s/epoch - 772ms/step
# Epoch 26/30
# 26/26 - 19s - loss: 0.0071 - accuracy: 0.9988 - val_loss: 5.8497 - val_accuracy: 0.2637 - 19s/epoch - 717ms/step
# Epoch 27/30
# 26/26 - 19s - loss: 0.0041 - accuracy: 0.9988 - val_loss: 6.1460 - val_accuracy: 0.2139 - 19s/epoch - 748ms/step
# Epoch 28/30
# 26/26 - 20s - loss: 0.0078 - accuracy: 0.9988 - val_loss: 5.9804 - val_accuracy: 0.2637 - 20s/epoch - 779ms/step
# Epoch 29/30
# 26/26 - 18s - loss: 0.0087 - accuracy: 0.9975 - val_loss: 5.9786 - val_accuracy: 0.2537 - 18s/epoch - 688ms/step
# Epoch 30/30
# 26/26 - 10s - loss: 0.0044 - accuracy: 0.9988 - val_loss: 6.0009 - val_accuracy: 0.2687 - 10s/epoch - 368ms/step
